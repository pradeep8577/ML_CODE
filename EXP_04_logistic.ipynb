# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('./insurance_data.csv')

# %%
df.head()
# Out:
#    age  bought_insurance
# 0   22                 0
# 1   25                 0
# 2   47                 1
# 3   52                 0
# 4   46                 1

# %%
plt.xlabel("age")
plt.ylabel("Have insurance?")
plt.scatter(df.age,df.bought_insurance,marker="+", color="red")

# %%
x = df.age
z = 1/(1 + 2.71828*np.exp(-df.bought_insurance))
plt.scatter(x,z,marker="+", color="red")
plt.plot(x, z)
plt.xlabel("age")
plt.ylabel("Have insurance?")  
plt.show()

# %%
X_train, X_test, y_train, y_test = train_test_split(df.age, df.bought_insurance, test_size=0.8)

# %%
X_train
# Out:
# 25    54
# 9     61
# 12    27
# 2     47
# 13    29
# Name: age, dtype: int64

# %%
y_train
# Out:
# 25    1
# 9     1
# 12    0
# 2     1
# 13    0
# Name: bought_insurance, dtype: int64

# %%
from sklearn import linear_model

# %%
logs = linear_model.LogisticRegression()

# %%
logs.fit(df[['age']],df.bought_insurance)
# Out:
# LogisticRegression()

# %%
logs.coef_
# Out:
# array([[0.1354656]])

# %%
logs.intercept_
# Out:
# array([-5.26279696])

# %%
logs.predict([[25]])
# Out:
# array([0], dtype=int64)

# %%
logs.predict([[45]])
# Out:
# array([1], dtype=int64)
